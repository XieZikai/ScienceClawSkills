# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import rdMolDraw2D
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
from rdkit.Geometry import Point3D
import sys

# ==================== 基础工具函数 ====================

def read_mol_file(filepath):
    mol = Chem.MolFromMolFile(filepath, removeHs=False)
    if mol is None:
        raise ValueError(f"无法读取mol文件: {filepath}")
    return mol

def find_aldehyde_groups(mol):
    groups = []
    for atom in mol.GetAtoms():
        if atom.GetSymbol() == 'C':
            for bond in atom.GetBonds():
                neighbor = bond.GetOtherAtom(atom)
                if neighbor.GetSymbol() == 'O' and bond.GetBondType() == Chem.BondType.DOUBLE:
                    if neighbor.GetDegree() == 1:
                        groups.append((atom.GetIdx(), neighbor.GetIdx()))
                        break
    return groups

def find_amine_nitrogens(mol):
    nitrogens = []
    for atom in mol.GetAtoms():
        if atom.GetSymbol() == 'N':
            h_count = atom.GetTotalNumHs()
            if h_count >= 2 and atom.GetDegree() == 1:
                nitrogens.append(atom.GetIdx())
    return nitrogens

def draw_molecule(mol, filepath, size=(1200, 900)):
    drawer = rdMolDraw2D.MolDraw2DCairo(size[0], size[1])
    drawer.drawOptions().addAtomIndices = False
    drawer.DrawMolecule(mol)
    drawer.FinishDrawing()
    with open(filepath, 'wb') as f:
        f.write(drawer.GetDrawingText())
    print(f"  结构图已保存: {filepath}")

def rotate_vec_2d(vec, angle_deg):
    angle = np.radians(angle_deg)
    cos_a, sin_a = np.cos(angle), np.sin(angle)
    return np.array([cos_a * vec[0] - sin_a * vec[1], sin_a * vec[0] + cos_a * vec[1]])

def mirror_point_along_axis(point, axis_origin, axis_dir):
    p_rel = point - axis_origin
    d = axis_dir / np.linalg.norm(axis_dir)
    p_mirror = 2 * np.dot(p_rel, d) * d - p_rel
    return p_mirror + axis_origin

def mirror_vec_along_axis(vec, axis_dir):
    d = axis_dir / np.linalg.norm(axis_dir)
    return 2 * np.dot(vec, d) * d - vec

def rotate_point(point, center, angle):
    """2D旋转点（只影响x,y，保留z如果存在）"""
    cos_a, sin_a = np.cos(angle), np.sin(angle)
    p = point[:2] - center[:2]
    rotated = np.array([cos_a * p[0] - sin_a * p[1], sin_a * p[0] + cos_a * p[1]])
    return rotated + center[:2]

def rotate_point_3d(point, center, angle):
    """2D旋转点，保留z坐标"""
    cos_a, sin_a = np.cos(angle), np.sin(angle)
    p = np.array([point[0] - center[0], point[1] - center[1]])
    rotated_xy = np.array([cos_a * p[0] - sin_a * p[1], sin_a * p[0] + cos_a * p[1]])
    z = point[2] if len(point) > 2 else 0
    return np.array([rotated_xy[0] + center[0], rotated_xy[1] + center[1], z])

def mirror_point_along_axis_3d(point, axis_origin, axis_dir):
    """沿轴镜像点，只影响x,y，保留z坐标"""
    p_rel = np.array([point[0] - axis_origin[0], point[1] - axis_origin[1]])
    d = axis_dir[:2] / np.linalg.norm(axis_dir[:2])
    p_mirror = 2 * np.dot(p_rel, d) * d - p_rel
    z = point[2] if len(point) > 2 else 0
    return np.array([p_mirror[0] + axis_origin[0], p_mirror[1] + axis_origin[1], z])

def get_edge_direction(conf, vertex_idx, all_vertices_idx):
    vertex_pos = np.array([conf.GetAtomPosition(vertex_idx).x, conf.GetAtomPosition(vertex_idx).y])
    min_dist = float('inf')
    nearest_pos = None
    for idx in all_vertices_idx:
        if idx == vertex_idx:
            continue
        pos = np.array([conf.GetAtomPosition(idx).x, conf.GetAtomPosition(idx).y])
        dist = np.linalg.norm(pos - vertex_pos)
        if dist < min_dist:
            min_dist = dist
            nearest_pos = pos
    edge_dir = nearest_pos - vertex_pos
    return edge_dir / np.linalg.norm(edge_dir)

def calc_edge_parallelism(ald_edge_dir, ami_edge_dir_original, ami_ny_dir, nc_dir, flip):
    current_edge = ami_edge_dir_original.copy()
    current_ny = ami_ny_dir.copy()
    if flip:
        current_edge = mirror_vec_along_axis(current_edge, current_ny)
    target_ny = rotate_vec_2d(nc_dir, 120)
    rot_angle = np.arctan2(target_ny[1], target_ny[0]) - np.arctan2(current_ny[1], current_ny[0])
    cos_r, sin_r = np.cos(rot_angle), np.sin(rot_angle)
    final_edge = np.array([
        cos_r * current_edge[0] - sin_r * current_edge[1],
        sin_r * current_edge[0] + cos_r * current_edge[1]
    ])
    return np.abs(np.dot(ald_edge_dir, final_edge))

# ==================== 分子合并函数 ====================

def determine_flip(ald_path, ami_path):
    """根据边平行度判断是否需要翻转"""
    ald_mol = read_mol_file(ald_path)
    ami_mol = read_mol_file(ami_path)
    # 不再调用Compute2DCoords，直接使用原有坐标
    
    ald_conf = ald_mol.GetConformer()
    ami_conf = ami_mol.GetConformer()
    
    ald_groups = find_aldehyde_groups(ald_mol)
    ami_nitrogens = find_amine_nitrogens(ami_mol)
    
    ald_c_indices = [g[0] for g in ald_groups]
    ald_c_idx, ald_o_idx = ald_groups[0]
    ami_n_idx = ami_nitrogens[0]
    
    ald_edge_dir = get_edge_direction(ald_conf, ald_c_idx, ald_c_indices)
    ami_edge_dir = get_edge_direction(ami_conf, ami_n_idx, ami_nitrogens)
    
    ami_n_atom = ami_mol.GetAtomWithIdx(ami_n_idx)
    ami_y_idx = None
    for neighbor in ami_n_atom.GetNeighbors():
        if neighbor.GetSymbol() == 'C':
            ami_y_idx = neighbor.GetIdx()
            break
    
    ami_n_pos = np.array([ami_conf.GetAtomPosition(ami_n_idx).x, ami_conf.GetAtomPosition(ami_n_idx).y])
    ami_y_pos = np.array([ami_conf.GetAtomPosition(ami_y_idx).x, ami_conf.GetAtomPosition(ami_y_idx).y])
    ami_ny_dir = (ami_y_pos - ami_n_pos) / np.linalg.norm(ami_y_pos - ami_n_pos)
    
    ald_c_pos = np.array([ald_conf.GetAtomPosition(ald_c_idx).x, ald_conf.GetAtomPosition(ald_c_idx).y])
    ald_o_pos = np.array([ald_conf.GetAtomPosition(ald_o_idx).x, ald_conf.GetAtomPosition(ald_o_idx).y])
    co_dir = ald_o_pos - ald_c_pos
    nc_dir = -co_dir / np.linalg.norm(co_dir)
    
    p_noflip = calc_edge_parallelism(ald_edge_dir, ami_edge_dir, ami_ny_dir, nc_dir, False)
    p_flip = calc_edge_parallelism(ald_edge_dir, ami_edge_dir, ami_ny_dir, nc_dir, True)
    
    dev_noflip = min(abs(p_noflip), 1 - abs(p_noflip))
    dev_flip = min(abs(p_flip), 1 - abs(p_flip))
    
    return dev_flip < dev_noflip, p_noflip, p_flip

def merge_with_2d_coords_and_track(ald_mol, ami_mol, flip=False):
    """合并分子并跟踪删除的顶点位置"""
    
    def snap_direction_to_standard(direction):
        """将方向舍入到最近的标准方向（30度的倍数）"""
        standard_angles = [i * 30 for i in range(12)]
        angle = np.degrees(np.arctan2(direction[1], direction[0]))
        if angle < 0:
            angle += 360
        
        # 找到最近的标准角度
        min_diff = float('inf')
        best_angle = 0
        for sa in standard_angles:
            diff = abs(angle - sa)
            if diff > 180:
                diff = 360 - diff
            if diff < min_diff:
                min_diff = diff
                best_angle = sa
        
        rad = np.radians(best_angle)
        return np.array([np.cos(rad), np.sin(rad)])
    
    # 不再调用Compute2DCoords，直接使用原有坐标
    
    ald_groups = find_aldehyde_groups(ald_mol)
    ami_nitrogens = find_amine_nitrogens(ami_mol)
    
    ald_c_idx, ald_o_idx = ald_groups[0]
    ami_n_idx = ami_nitrogens[0]
    
    ald_conf = ald_mol.GetConformer()
    ami_conf = ami_mol.GetConformer()
    
    # 记录ald所有CHO的位置和方向
    ald_vertex_info = []
    for i, (c_idx, o_idx) in enumerate(ald_groups):
        if i == 0:
            continue
        c_pos = np.array([ald_conf.GetAtomPosition(c_idx).x, ald_conf.GetAtomPosition(c_idx).y])
        c_atom = ald_mol.GetAtomWithIdx(c_idx)
        ring_c_idx = None
        for neighbor in c_atom.GetNeighbors():
            if neighbor.GetIdx() != o_idx:
                ring_c_idx = neighbor.GetIdx()
                break
        ring_c_pos = np.array([ald_conf.GetAtomPosition(ring_c_idx).x, ald_conf.GetAtomPosition(ring_c_idx).y])
        direction = c_pos - ring_c_pos
        direction = direction / np.linalg.norm(direction)
        # 舍入到标准方向
        direction = snap_direction_to_standard(direction)
        ald_vertex_info.append((ring_c_idx, ring_c_pos, direction))
    
    # 记录ami所有NH2的位置和方向
    ami_vertex_info = []
    for i, n_idx in enumerate(ami_nitrogens):
        if i == 0:
            continue
        n_pos = np.array([ami_conf.GetAtomPosition(n_idx).x, ami_conf.GetAtomPosition(n_idx).y])
        n_atom = ami_mol.GetAtomWithIdx(n_idx)
        ring_c_idx = None
        for neighbor in n_atom.GetNeighbors():
            if neighbor.GetSymbol() == 'C':
                ring_c_idx = neighbor.GetIdx()
                break
        ring_c_pos = np.array([ami_conf.GetAtomPosition(ring_c_idx).x, ami_conf.GetAtomPosition(ring_c_idx).y])
        direction = n_pos - ring_c_pos
        direction = direction / np.linalg.norm(direction)
        # 舍入到标准方向
        direction = snap_direction_to_standard(direction)
        ami_vertex_info.append((ring_c_idx, ring_c_pos, direction))
    
    # 对ami进行变换
    ald_c_pos = np.array([ald_conf.GetAtomPosition(ald_c_idx).x, ald_conf.GetAtomPosition(ald_c_idx).y])
    ald_o_pos = np.array([ald_conf.GetAtomPosition(ald_o_idx).x, ald_conf.GetAtomPosition(ald_o_idx).y])
    
    ami_n_pos = np.array([ami_conf.GetAtomPosition(ami_n_idx).x, ami_conf.GetAtomPosition(ami_n_idx).y])
    ami_n_atom = ami_mol.GetAtomWithIdx(ami_n_idx)
    ami_y_idx = None
    for neighbor in ami_n_atom.GetNeighbors():
        if neighbor.GetSymbol() == 'C':
            ami_y_idx = neighbor.GetIdx()
            break
    ami_y_pos = np.array([ami_conf.GetAtomPosition(ami_y_idx).x, ami_conf.GetAtomPosition(ami_y_idx).y])
    
    # 翻转
    if flip:
        ny_dir = ami_y_pos - ami_n_pos
        for i in range(ami_mol.GetNumAtoms()):
            pos = ami_conf.GetAtomPosition(i)
            p = np.array([pos.x, pos.y])
            p_new = mirror_point_along_axis(p, ami_n_pos, ny_dir)
            ami_conf.SetAtomPosition(i, Point3D(p_new[0], p_new[1], pos.z))  # 保留z坐标
        for j in range(len(ami_vertex_info)):
            ring_c_idx, ring_c_pos, direction = ami_vertex_info[j]
            new_ring_c_pos = np.array([ami_conf.GetAtomPosition(ring_c_idx).x, ami_conf.GetAtomPosition(ring_c_idx).y])
            new_direction = mirror_vec_along_axis(direction, ny_dir)
            ami_vertex_info[j] = (ring_c_idx, new_ring_c_pos, new_direction)
        ami_y_pos = np.array([ami_conf.GetAtomPosition(ami_y_idx).x, ami_conf.GetAtomPosition(ami_y_idx).y])
    
    target_n_pos = ald_o_pos
    cn_dir = target_n_pos - ald_c_pos
    cn_dir = cn_dir / np.linalg.norm(cn_dir)
    nc_dir = -cn_dir
    #target_ny_dir = rotate_vec_2d(nc_dir, -120)
 
    target_ny_dir = rotate_vec_2d(nc_dir, 120)
    current_ny_dir = ami_y_pos - ami_n_pos
    current_ny_dir = current_ny_dir / np.linalg.norm(current_ny_dir)
    
    rot_angle = np.arctan2(target_ny_dir[1], target_ny_dir[0]) - np.arctan2(current_ny_dir[1], current_ny_dir[0])
    cos_r, sin_r = np.cos(rot_angle), np.sin(rot_angle)
    
    ami_n_pos = np.array([ami_conf.GetAtomPosition(ami_n_idx).x, ami_conf.GetAtomPosition(ami_n_idx).y])
    
    # 旋转ami分子
    for i in range(ami_mol.GetNumAtoms()):
        pos = ami_conf.GetAtomPosition(i)
        p = np.array([pos.x, pos.y]) - ami_n_pos
        new_p = np.array([cos_r * p[0] - sin_r * p[1], sin_r * p[0] + cos_r * p[1]])
        new_p = new_p + ami_n_pos
        ami_conf.SetAtomPosition(i, Point3D(new_p[0], new_p[1], pos.z))  # 保留z坐标
    
    for j in range(len(ami_vertex_info)):
        ring_c_idx, ring_c_pos, direction = ami_vertex_info[j]
        new_ring_c_pos = np.array([ami_conf.GetAtomPosition(ring_c_idx).x, ami_conf.GetAtomPosition(ring_c_idx).y])
        new_direction = np.array([cos_r * direction[0] - sin_r * direction[1], sin_r * direction[0] + cos_r * direction[1]])
        ami_vertex_info[j] = (ring_c_idx, new_ring_c_pos, new_direction)
    
    # 平移ami分子
    ami_n_pos_new = np.array([ami_conf.GetAtomPosition(ami_n_idx).x, ami_conf.GetAtomPosition(ami_n_idx).y])
    translation = target_n_pos - ami_n_pos_new
    for i in range(ami_mol.GetNumAtoms()):
        pos = ami_conf.GetAtomPosition(i)
        ami_conf.SetAtomPosition(i, Point3D(pos.x + translation[0], pos.y + translation[1], pos.z))  # 保留z坐标
    
    for j in range(len(ami_vertex_info)):
        ring_c_idx, ring_c_pos, direction = ami_vertex_info[j]
        new_ring_c_pos = np.array([ami_conf.GetAtomPosition(ring_c_idx).x, ami_conf.GetAtomPosition(ring_c_idx).y])
        ami_vertex_info[j] = (ring_c_idx, new_ring_c_pos, direction)
    
    # 合并分子
    combined = Chem.RWMol(Chem.CombineMols(ald_mol, ami_mol))
    offset = ald_mol.GetNumAtoms()
    ami_n_combined_idx = ami_n_idx + offset
    
    for j in range(len(ami_vertex_info)):
        ring_c_idx, ring_c_pos, direction = ami_vertex_info[j]
        ami_vertex_info[j] = (ring_c_idx + offset, ring_c_pos, direction)
    
    combined.RemoveBond(ald_c_idx, ald_o_idx)
    combined.RemoveAtom(ald_o_idx)
    
    def update_idx(idx, removed_idx):
        return idx - 1 if removed_idx < idx else idx
    
    ami_n_combined_idx = update_idx(ami_n_combined_idx, ald_o_idx)
    ald_c_idx = update_idx(ald_c_idx, ald_o_idx)
    for j in range(len(ald_vertex_info)):
        ring_c_idx, ring_c_pos, direction = ald_vertex_info[j]
        ald_vertex_info[j] = (update_idx(ring_c_idx, ald_o_idx), ring_c_pos, direction)
    for j in range(len(ami_vertex_info)):
        ring_c_idx, ring_c_pos, direction = ami_vertex_info[j]
        ami_vertex_info[j] = (update_idx(ring_c_idx, ald_o_idx), ring_c_pos, direction)
    
    imine_c_idx = ald_c_idx
    imine_n_idx = ami_n_combined_idx
    
    combined.AddBond(ald_c_idx, ami_n_combined_idx, Chem.BondType.DOUBLE)
    
    # 删除剩余的CHO
    while True:
        combined.UpdatePropertyCache(strict=False)
        ald_groups_remaining = find_aldehyde_groups(combined)
        if not ald_groups_remaining:
            break
        c_idx, o_idx = ald_groups_remaining[-1]
        c_atom = combined.GetAtomWithIdx(c_idx)
        ring_c_idx = None
        for neighbor in c_atom.GetNeighbors():
            if neighbor.GetSymbol() == 'C' and neighbor.GetIsAromatic():
                ring_c_idx = neighbor.GetIdx()
                break
        combined.RemoveBond(c_idx, o_idx)
        if ring_c_idx is not None:
            combined.RemoveBond(c_idx, ring_c_idx)
        atoms_to_remove = sorted([c_idx, o_idx], reverse=True)
        for rem_idx in atoms_to_remove:
            combined.RemoveAtom(rem_idx)
            imine_c_idx = update_idx(imine_c_idx, rem_idx)
            imine_n_idx = update_idx(imine_n_idx, rem_idx)
            for j in range(len(ald_vertex_info)):
                idx, pos, direction = ald_vertex_info[j]
                ald_vertex_info[j] = (update_idx(idx, rem_idx), pos, direction)
            for j in range(len(ami_vertex_info)):
                idx, pos, direction = ami_vertex_info[j]
                ami_vertex_info[j] = (update_idx(idx, rem_idx), pos, direction)
    
    # 删除剩余的NH2
    while True:
        combined.UpdatePropertyCache(strict=False)
        ami_nitrogens_remaining = find_amine_nitrogens(combined)
        if not ami_nitrogens_remaining:
            break
        n_idx = ami_nitrogens_remaining[-1]
        n_atom = combined.GetAtomWithIdx(n_idx)
        ring_c_idx = None
        for neighbor in n_atom.GetNeighbors():
            if neighbor.GetSymbol() == 'C':
                ring_c_idx = neighbor.GetIdx()
                break
        if ring_c_idx is not None:
            combined.RemoveBond(n_idx, ring_c_idx)
        combined.RemoveAtom(n_idx)
        imine_c_idx = update_idx(imine_c_idx, n_idx)
        imine_n_idx = update_idx(imine_n_idx, n_idx)
        for j in range(len(ald_vertex_info)):
            idx, pos, direction = ald_vertex_info[j]
            ald_vertex_info[j] = (update_idx(idx, n_idx), pos, direction)
        for j in range(len(ami_vertex_info)):
            idx, pos, direction = ami_vertex_info[j]
            ami_vertex_info[j] = (update_idx(idx, n_idx), pos, direction)
    
    Chem.SanitizeMol(combined)
    
    return combined.GetMol(), imine_c_idx, imine_n_idx, ald_vertex_info, ami_vertex_info

def add_vertex_atoms(mol, ald_vertex_info, ami_vertex_info, bond_length=1.4):
    """在顶点位置添加C和N原子"""
    mol_rw = Chem.RWMol(mol)
    conf = mol_rw.GetConformer()
    
    new_c_coords = []
    new_n_coords = []
    new_c_indices = []
    new_n_indices = []
    c_ring_indices = []
    n_ring_indices = []
    
    for ring_c_idx, ring_c_pos_recorded, direction in ald_vertex_info:
        # 使用mol中的实际坐标，而不是记录的坐标
        actual_pos = np.array([conf.GetAtomPosition(ring_c_idx).x, conf.GetAtomPosition(ring_c_idx).y])
        new_pos = actual_pos + direction * bond_length
        new_c_coords.append(new_pos)
        c_ring_indices.append(ring_c_idx)
        new_idx = mol_rw.AddAtom(Chem.Atom(6))
        new_c_indices.append(new_idx)
        conf.SetAtomPosition(new_idx, Point3D(new_pos[0], new_pos[1], 0))
        mol_rw.AddBond(ring_c_idx, new_idx, Chem.BondType.SINGLE)
    
    for ring_c_idx, ring_c_pos_recorded, direction in ami_vertex_info:
        # 使用mol中的实际坐标，而不是记录的坐标
        actual_pos = np.array([conf.GetAtomPosition(ring_c_idx).x, conf.GetAtomPosition(ring_c_idx).y])
        new_pos = actual_pos + direction * bond_length
        new_n_coords.append(new_pos)
        n_ring_indices.append(ring_c_idx)
        new_idx = mol_rw.AddAtom(Chem.Atom(7))
        new_n_indices.append(new_idx)
        conf.SetAtomPosition(new_idx, Point3D(new_pos[0], new_pos[1], 0))
        mol_rw.AddBond(ring_c_idx, new_idx, Chem.BondType.SINGLE)
    
    Chem.SanitizeMol(mol_rw)
    return mol_rw.GetMol(), new_c_coords, new_n_coords, new_c_indices, new_n_indices, c_ring_indices, n_ring_indices

# ==================== 网格对齐函数 ====================

def find_corner_vertex(coords):
    """找到3个顶点中的'角落'顶点（距离另外两个之和最小）"""
    coords = np.array(coords)
    n = len(coords)
    dist_sums = []
    for i in range(n):
        dist_sum = sum(np.linalg.norm(coords[i] - coords[j]) for j in range(n) if j != i)
        dist_sums.append(dist_sum)
    corner_idx = np.argmin(dist_sums)
    other_indices = [i for i in range(n) if i != corner_idx]
    return corner_idx, other_indices

def get_rotation_angle_to_align_axes(corner_pos, adj1_pos, adj2_pos):
    """计算需要旋转的角度，使直角与xy轴平行"""
    vec1 = adj1_pos - corner_pos
    vec1 = vec1 / np.linalg.norm(vec1)
    
    angle1 = np.arctan2(vec1[1], vec1[0])
    target_angles = [0, np.pi/2, np.pi, -np.pi/2]
    
    best_angle = 0
    best_diff = float('inf')
    for target in target_angles:
        diff = abs(angle1 - target)
        if diff > np.pi:
            diff = 2 * np.pi - diff
        if diff < best_diff:
            best_diff = diff
            best_angle = target - angle1
    
    return best_angle

def find_imine_bond(mol):
    """找到imine键（C=N双键）"""
    conf = mol.GetConformer()
    for bond in mol.GetBonds():
        if bond.GetBondType() == Chem.BondType.DOUBLE:
            a1 = bond.GetBeginAtom()
            a2 = bond.GetEndAtom()
            if (a1.GetSymbol() == 'C' and a2.GetSymbol() == 'N') or \
               (a1.GetSymbol() == 'N' and a2.GetSymbol() == 'C'):
                if a1.GetSymbol() == 'C':
                    c_idx, n_idx = a1.GetIdx(), a2.GetIdx()
                else:
                    c_idx, n_idx = a2.GetIdx(), a1.GetIdx()
                return c_idx, n_idx
    return None, None

def get_fragment_atoms(mol, start_idx, exclude_idx):
    """通过BFS获取从start_idx开始、不经过exclude_idx的所有原子"""
    visited = set([exclude_idx])
    queue = [start_idx]
    fragment = []
    
    while queue:
        idx = queue.pop(0)
        if idx in visited:
            continue
        visited.add(idx)
        fragment.append(idx)
        atom = mol.GetAtomWithIdx(idx)
        for neighbor in atom.GetNeighbors():
            n_idx = neighbor.GetIdx()
            if n_idx not in visited:
                queue.append(n_idx)
    
    return fragment

def align_to_grid(mol, c_coords, n_coords):
    """对齐分子使顶点形成的直角与xy轴平行"""
    mol_rw = Chem.RWMol(mol)
    conf = mol_rw.GetConformer()
    
    new_c_coords = [np.array(c) for c in c_coords]
    new_n_coords = [np.array(n) for n in n_coords]
    
    imine_c_idx, imine_n_idx = find_imine_bond(mol_rw)
    
    # ========== 步骤1：旋转整个分子使C顶点的直角与xy轴平行 ==========
    c_corner_idx, c_adj_indices = find_corner_vertex(new_c_coords)
    c_corner = new_c_coords[c_corner_idx]
    c_adj1 = new_c_coords[c_adj_indices[0]]
    c_adj2 = new_c_coords[c_adj_indices[1]]
    
    c_rot_angle = get_rotation_angle_to_align_axes(c_corner, c_adj1, c_adj2)
    
    if abs(c_rot_angle) > 0.001:
        for i in range(mol_rw.GetNumAtoms()):
            pos = conf.GetAtomPosition(i)
            p = np.array([pos.x, pos.y])
            new_p = rotate_point(p, np.array([0, 0]), c_rot_angle)
            conf.SetAtomPosition(i, Point3D(new_p[0], new_p[1], pos.z))  # 保留z坐标
        
        for i in range(len(new_c_coords)):
            new_c_coords[i] = rotate_point(new_c_coords[i], np.array([0, 0]), c_rot_angle)
        for i in range(len(new_n_coords)):
            new_n_coords[i] = rotate_point(new_n_coords[i], np.array([0, 0]), c_rot_angle)
    
    # ========== 步骤2：旋转ami片段使N顶点的直角与xy轴平行 ==========
    n_corner_idx, n_adj_indices = find_corner_vertex(new_n_coords)
    n_corner = new_n_coords[n_corner_idx]
    n_adj1 = new_n_coords[n_adj_indices[0]]
    n_adj2 = new_n_coords[n_adj_indices[1]]
    
    n_rot_angle = get_rotation_angle_to_align_axes(n_corner, n_adj1, n_adj2)
    
    if abs(n_rot_angle) > 0.001:
        ami_atoms = get_fragment_atoms(mol_rw, imine_n_idx, imine_c_idx)
        imine_c_pos = np.array([conf.GetAtomPosition(imine_c_idx).x, conf.GetAtomPosition(imine_c_idx).y])
        
        for atom_idx in ami_atoms:
            pos = conf.GetAtomPosition(atom_idx)
            p = np.array([pos.x, pos.y])
            new_p = rotate_point(p, imine_c_pos, n_rot_angle)
            conf.SetAtomPosition(atom_idx, Point3D(new_p[0], new_p[1], pos.z))  # 保留z坐标
        
        for i in range(len(new_n_coords)):
            new_n_coords[i] = rotate_point(new_n_coords[i], imine_c_pos, n_rot_angle)
    
    Chem.SanitizeMol(mol_rw)
    return mol_rw.GetMol(), new_c_coords, new_n_coords

# ==================== 补氢函数 ====================

def add_hydrogens_to_dimer(mol):
    """
    对dimer分子补氢：
    1. 用RDKit补氢
    2. 删除C顶点和N顶点上的H
    3. 对C顶点补2个H（sp2杂化，120度夹角）
    4. 根据imine键取向删除与对应轴更平行的H
    """
    
    # 找到aligned_mol中最后三个C原子和最后三个N原子（它们是新增的顶点原子）
    num_atoms = mol.GetNumAtoms()
    c_vertex_indices = []
    n_vertex_indices = []
    
    # 从后往前找，找到最后3个C和最后3个N
    for i in range(num_atoms - 1, -1, -1):
        atom = mol.GetAtomWithIdx(i)
        if atom.GetSymbol() == 'C' and len(c_vertex_indices) < 3:
            c_vertex_indices.append(i)
        elif atom.GetSymbol() == 'N' and len(n_vertex_indices) < 3:
            n_vertex_indices.append(i)
        if len(c_vertex_indices) == 3 and len(n_vertex_indices) == 3:
            break
    
    c_vertex_indices.sort()
    n_vertex_indices.sort()
    
    print(f"  C顶点索引: {c_vertex_indices}")
    print(f"  N顶点索引: {n_vertex_indices}")
    
    # Step 1: 用RDKit补氢
    mol_h = Chem.AddHs(mol, addCoords=True)
    print(f"  RDKit补氢后原子数: {mol_h.GetNumAtoms()}")
    
    # Step 2: 删除C顶点和N顶点上的H
    h_to_remove = []
    for idx in c_vertex_indices + n_vertex_indices:
        atom = mol_h.GetAtomWithIdx(idx)
        for neighbor in atom.GetNeighbors():
            if neighbor.GetSymbol() == 'H':
                h_to_remove.append(neighbor.GetIdx())
    
    print(f"  删除顶点H数: {len(h_to_remove)}")
    
    mol_rw = Chem.RWMol(mol_h)
    for h_idx in sorted(h_to_remove, reverse=True):
        mol_rw.RemoveAtom(h_idx)
    
    Chem.SanitizeMol(mol_rw)
    
    # Step 3: 对C顶点补2个H（120度夹角）
    # C顶点索引在删除H后不变（因为H索引都比C大）
    conf_rw = mol_rw.GetConformer()
    
    h_bond_length = 1.0
    for c_idx in c_vertex_indices:
        c_atom = mol_rw.GetAtomWithIdx(c_idx)
        c_pos = np.array([conf_rw.GetAtomPosition(c_idx).x, conf_rw.GetAtomPosition(c_idx).y])
        
        ring_c = list(c_atom.GetNeighbors())[0]
        ring_c_pos = np.array([conf_rw.GetAtomPosition(ring_c.GetIdx()).x, 
                              conf_rw.GetAtomPosition(ring_c.GetIdx()).y])
        
        d = c_pos - ring_c_pos
        d = d / np.linalg.norm(d)
        
        h1_dir = rotate_vec_2d(d, 60)
        h2_dir = rotate_vec_2d(d, -60)
        
        h1_pos = c_pos + h1_dir * h_bond_length
        h2_pos = c_pos + h2_dir * h_bond_length
        
        h1_idx = mol_rw.AddAtom(Chem.Atom(1))
        conf_rw.SetAtomPosition(h1_idx, Point3D(h1_pos[0], h1_pos[1], 0))
        mol_rw.AddBond(c_idx, h1_idx, Chem.BondType.SINGLE)
        
        h2_idx = mol_rw.AddAtom(Chem.Atom(1))
        conf_rw.SetAtomPosition(h2_idx, Point3D(h2_pos[0], h2_pos[1], 0))
        mol_rw.AddBond(c_idx, h2_idx, Chem.BondType.SINGLE)
    
    Chem.SanitizeMol(mol_rw)
    print(f"  补C顶点H后原子数: {mol_rw.GetNumAtoms()}")
    
    # Step 4: 根据imine键取向删除H
    imine_c_idx, imine_n_idx = find_imine_bond(mol_rw)
    conf_rw = mol_rw.GetConformer()
    c_pos_imine = np.array([conf_rw.GetAtomPosition(imine_c_idx).x, conf_rw.GetAtomPosition(imine_c_idx).y])
    n_pos_imine = np.array([conf_rw.GetAtomPosition(imine_n_idx).x, conf_rw.GetAtomPosition(imine_n_idx).y])
    imine_vec = n_pos_imine - c_pos_imine
    imine_vec = imine_vec / np.linalg.norm(imine_vec)
    
    if abs(imine_vec[0]) > abs(imine_vec[1]):
        imine_axis = 'X'
    else:
        imine_axis = 'Y'
    print(f"  Imine键与{imine_axis}轴更平行")
    
    # 只处理c_vertex_indices中的C原子
    h_to_remove = []
    for c_idx in c_vertex_indices:
        c_atom = mol_rw.GetAtomWithIdx(c_idx)
        c_pos = np.array([conf_rw.GetAtomPosition(c_idx).x, conf_rw.GetAtomPosition(c_idx).y])
        
        h_list = []
        for neighbor in c_atom.GetNeighbors():
            if neighbor.GetSymbol() == 'H':
                h_idx = neighbor.GetIdx()
                h_pos = np.array([conf_rw.GetAtomPosition(h_idx).x, conf_rw.GetAtomPosition(h_idx).y])
                ch_vec = h_pos - c_pos
                ch_vec = ch_vec / np.linalg.norm(ch_vec)
                
                if imine_axis == 'X':
                    parallelism = abs(ch_vec[0])
                else:
                    parallelism = abs(ch_vec[1])
                
                h_list.append((h_idx, parallelism))
        
        h_list.sort(key=lambda x: x[1], reverse=True)
        h_to_remove.append(h_list[0][0])
        print(f"    C({c_idx}): 删除H({h_list[0][0]}), 平行度={h_list[0][1]:.3f}")
    
    for h_idx in sorted(h_to_remove, reverse=True):
        mol_rw.RemoveAtom(h_idx)
    
    Chem.SanitizeMol(mol_rw)
    print(f"  最终原子数: {mol_rw.GetNumAtoms()}")
    
    return mol_rw.GetMol(),imine_axis

# ==================== 主函数 ====================

def main(ald_path, ami_path, output_prefix):
    print("=" * 70)
    print("  COF Dimer 完整流程")
    print("=" * 70)
    
    print("\n[1. 读取分子文件]")
    print(f"  ald: {ald_path}")
    print(f"  ami: {ami_path}")
    
    # 判断是否需要翻转
    print("\n[2. 计算边平行度]")
    flip, p_noflip, p_flip = determine_flip(ald_path, ami_path)
    dev_noflip = min(abs(p_noflip), 1 - abs(p_noflip))
    dev_flip = min(abs(p_flip), 1 - abs(p_flip))
    print(f"  不翻转: 边平行度 = {p_noflip:.4f}, 偏离 = {dev_noflip:.4f}")
    print(f"  翻转: 边平行度 = {p_flip:.4f}, 偏离 = {dev_flip:.4f}")
    print(f"  ✓ 选择: {'翻转' if flip else '不翻转'}")
    
    # 合并分子
    print("\n[3. 合并分子]")
    mol, c_idx, n_idx, ald_vertex_info, ami_vertex_info = merge_with_2d_coords_and_track(
        read_mol_file(ald_path),
        read_mol_file(ami_path),
        flip=flip
    )
    print(f"  ald剩余顶点: {len(ald_vertex_info)}")
    print(f"  ami剩余顶点: {len(ami_vertex_info)}")
    
    # 添加顶点原子
    print("\n[4. 添加顶点原子]")
    mol_with_vertices, new_c_coords, new_n_coords, c_indices, n_indices, c_ring_indices, n_ring_indices = add_vertex_atoms(
        mol, ald_vertex_info, ami_vertex_info
    )
    print(f"  添加C顶点: {len(new_c_coords)}个")
    print(f"  添加N顶点: {len(new_n_coords)}个")
    
    # 对齐到网格
    print("\n[5. 对齐到网格]")
    mol_aligned, aligned_c_coords, aligned_n_coords = align_to_grid(
        mol_with_vertices, new_c_coords, new_n_coords
    )
    print("  C顶点坐标:")
    for i, coord in enumerate(aligned_c_coords):
        print(f"    C{i+1}: ({coord[0]:.4f}, {coord[1]:.4f})")
    print("  N顶点坐标:")
    for i, coord in enumerate(aligned_n_coords):
        print(f"    N{i+1}: ({coord[0]:.4f}, {coord[1]:.4f})")
    
    # 补氢
    print("\n[6. 补氢]")
    mol_final,imine_axis = add_hydrogens_to_dimer(mol_aligned)
    
    # 保存最终结果
    print("\n[7. 保存结果]")
    final_mol_path = f"{output_prefix}_final.mol"
    final_png_path = f"{output_prefix}_final.png"
    Chem.MolToMolFile(mol_final, final_mol_path)
    print(f"  MOL文件: {final_mol_path}")
    draw_molecule(mol_final, final_png_path)
    
    # 同时保存中间结果
    aligned_mol_path = f"{output_prefix}_aligned.mol"
    Chem.MolToMolFile(mol_aligned, aligned_mol_path)
    print(f"  对齐MOL文件: {aligned_mol_path}")
    
    print("\n" + "=" * 70)
    print("完成!")
    print("=" * 70)
    
    return mol_final,np.array(aligned_c_coords),np.array(aligned_n_coords),imine_axis

# %%
# Cell 参数：a，b
import numpy as np

def max_axis_distance(A: np.ndarray, B: np.ndarray):
    A = np.asarray(A)
    B = np.asarray(B)
    assert A.shape == (3, 2) and B.shape == (3, 2)

    Ax, Ay = A[:, 0], A[:, 1]
    Bx, By = B[:, 0], B[:, 1]

    Dx = max(abs(Ax.max() - Bx.min()), abs(Bx.max() - Ax.min()))
    Dy = max(abs(Ay.max() - By.min()), abs(By.max() - Ay.min()))
    return Dx, Dy

import glob,os
# 注意需要跑两次
### 第一次：角度为120度 target_ny_dir = rotate_vec_2d(nc_dir, 120) 
ald_mols=glob.glob('ald-result/*.mol')
os.makedirs('cif_results',exist_ok=True)
ald_mols=glob.glob('ald-result/*.mol')
ami_mols=glob.glob('ami-result/*.mol')
### 第二次：角度为-120度 # target_ny_dir = rotate_vec_2d(nc_dir, -120)

#nums=[9,15,17,18,19,20,21,23,24,26,28,30,33,34,36,37,38,39,40]
#ald_mols=[f'ald-result/ald-{n}.mol' for n in nums]


for ald_path in ald_mols:
    for ami_path in ami_mols:
        ald_id = ald_path.split('ald-')[-1].split('.')[-2]
        ami_id = ami_path.split('ami-')[-1].split('.')[-2]
        output_prefix=f"./cif_results/dimer_ald-{ald_id}_ami-{ami_id}"
        final_mol,aligned_c_coords,aligned_n_coords,imine_axis=main(ald_path, ami_path, output_prefix)
        a,b=max_axis_distance(aligned_c_coords,aligned_n_coords)
        if imine_axis=='X':
            a+=1.5
        else:
            b+=1.5
        # 测试：搭建CIF文件
        from ase.io import read, write
        from ase import Atoms
        import numpy as np

        output_prefix=f"./cif_results/dimer_ald-{ald_id}_ami-{ami_id}"
        # 读取mol文件（单个重复单元）
        mol = read(f'{output_prefix}_final.mol')

        # 定义晶胞（斜方晶系示例）
        # a, b 是平面内的周期矢量长度
        # gamma 是a和b之间的夹角（斜着复制的关键）
        # c 是层间距
        a = a   
        b = b
        c = 12   
        alpha = 90
        beta = 90
        gamma = 90 
        mol.set_cell([a, b, c, alpha, beta, gamma])
        mol.set_pbc(True)

        # 关键：调整边界原子位置，使其在周期性边界处正确成键
        # 这需要根据你的具体结构手动调整

        mol.center()
        write(f'{output_prefix}.cif', mol)
# Out:
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-1.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-10.4530, 12.9057)
#     N2: (-10.4504, 2.6830)
#     N3: (-3.0526, 12.9073)
#
# [6. 补氢]
#   C顶点索引: [40, 41, 42]
#   N顶点索引: [43, 44, 45]
#   RDKit补氢后原子数: 84
#   删除顶点H数: 15
#   补C顶点H后原子数: 75
#   Imine键与X轴更平行
#     C(40): 删除H(70), 平行度=1.000
#     C(41): 删除H(71), 平行度=1.000
#     C(42): 删除H(74), 平行度=1.000
#   最终原子数: 72
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-1_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-1_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-1_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-10.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-10.4524, 15.5061)
#     N2: (-10.4521, 2.6842)
#     N3: (-3.0507, 15.5062)
#
# [6. 补氢]
#   C顶点索引: [44, 45, 46]
#   N顶点索引: [47, 48, 49]
#   RDKit补氢后原子数: 88
#   删除顶点H数: 15
#   补C顶点H后原子数: 79
#   Imine键与X轴更平行
#     C(44): 删除H(74), 平行度=1.000
#     C(45): 删除H(75), 平行度=1.000
#     C(46): 删除H(78), 平行度=1.000
#   最终原子数: 76
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-10_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-10_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-10_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-11.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0528, 20.7056)
#     N2: (-14.9498, 2.6827)
#     N3: (-14.9515, 20.7026)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 124
#   删除顶点H数: 15
#   补C顶点H后原子数: 115
#   Imine键与X轴更平行
#     C(64): 删除H(110), 平行度=1.000
#     C(65): 删除H(111), 平行度=1.000
#     C(66): 删除H(114), 平行度=1.000
#   最终原子数: 112
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-11_final.mol
# [21:31:44] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:44] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:44] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:44] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-1_ami-11_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-11_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-12.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.5016, 偏离 = 0.4984
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0170, 12.9009)
#     N2: (-23.9121, 12.9009)
#     N3: (-23.9360, 2.6989)
#
# [6. 补氢]
#   C顶点索引: [58, 59, 60]
#   N顶点索引: [61, 62, 63]
#   RDKit补氢后原子数: 114
#   删除顶点H数: 15
#   补C顶点H后原子数: 105
#   Imine键与X轴更平行
#     C(58): 删除H(100), 平行度=1.000
#     C(59): 删除H(101), 平行度=1.000
#     C(60): 删除H(104), 平行度=1.000
#   最终原子数: 102
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-12_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-12_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-12_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-13.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0465, 20.7035)
#     N2: (-19.4486, 2.6832)
#     N3: (-19.4549, 20.7024)
#
# [6. 补氢]
#   C顶点索引: [78, 79, 80]
#   N顶点索引: [81, 82, 83]
#   RDKit补氢后原子数: 146
#   删除顶点H数: 15
#   补C顶点H后原子数: 137
#   Imine键与X轴更平行
#     C(78): 删除H(132), 平行度=1.000
#     C(79): 删除H(133), 平行度=1.000
#     C(80): 删除H(136), 平行度=1.000
#   最终原子数: 134
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-13_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-13_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-13_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-14.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.4998, 偏离 = 0.4998
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0495, 7.7076)
#     N2: (-10.4524, 7.7084)
#     N3: (-10.4527, 2.6850)
#
# [6. 补氢]
#   C顶点索引: [26, 27, 28]
#   N顶点索引: [29, 30, 31]
#   RDKit补氢后原子数: 60
#   删除顶点H数: 15
#   补C顶点H后原子数: 51
#   Imine键与X轴更平行
#     C(26): 删除H(46), 平行度=1.000
#     C(27): 删除H(47), 平行度=1.000
#     C(28): 删除H(50), 平行度=1.000
#   最终原子数: 48
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-14_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-14_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-14_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-15.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.5016, 偏离 = 0.4984
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0176, 12.9005)
#     N2: (-23.9346, 2.6986)
#     N3: (-23.9110, 12.9005)
#
# [6. 补氢]
#   C顶点索引: [61, 62, 63]
#   N顶点索引: [64, 65, 66]
#   RDKit补氢后原子数: 115
#   删除顶点H数: 15
#   补C顶点H后原子数: 106
#   Imine键与X轴更平行
#     C(61): 删除H(101), 平行度=1.000
#     C(62): 删除H(102), 平行度=1.000
#     C(63): 删除H(105), 平行度=1.000
#   最终原子数: 103
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-15_final.mol
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-1_ami-15_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-15_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-16.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0017, 偏离 = 0.0017
#   翻转: 边平行度 = 0.8670, 偏离 = 0.1330
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0682, 23.2765)
#     N2: (-19.4815, 2.6804)
#     N3: (-19.4939, 23.2765)
#
# [6. 补氢]
#   C顶点索引: [78, 79, 80]
#   N顶点索引: [81, 82, 83]
#   RDKit补氢后原子数: 144
#   删除顶点H数: 15
#   补C顶点H后原子数: 135
#   Imine键与X轴更平行
#     C(78): 删除H(130), 平行度=1.000
#     C(79): 删除H(131), 平行度=1.000
#     C(80): 删除H(134), 平行度=1.000
#   最终原子数: 132
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-16_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-16_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-16_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-17.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.4996, 偏离 = 0.4996
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0464, 15.5056)
#     N2: (-19.4494, 15.5089)
#     N3: (-19.4534, 2.6876)
#
# [6. 补氢]
#   C顶点索引: [56, 57, 58]
#   N顶点索引: [59, 60, 61]
#   RDKit补氢后原子数: 110
#   删除顶点H数: 15
#   补C顶点H后原子数: 101
#   Imine键与X轴更平行
#     C(56): 删除H(96), 平行度=1.000
#     C(57): 删除H(97), 平行度=1.000
#     C(58): 删除H(100), 平行度=1.000
#   最终原子数: 98
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-17_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-17_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-17_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-18.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.8665, 偏离 = 0.1335
#   翻转: 边平行度 = 0.0007, 偏离 = 0.0007
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0258, 20.6822)
#     N2: (-17.9729, 2.6929)
#     N3: (-17.9485, 20.6907)
#
# [6. 补氢]
#   C顶点索引: [62, 63, 64]
#   N顶点索引: [65, 66, 67]
#   RDKit补氢后原子数: 112
#   删除顶点H数: 15
#   补C顶点H后原子数: 103
#   Imine键与X轴更平行
#     C(62): 删除H(98), 平行度=1.000
#     C(63): 删除H(99), 平行度=1.000
#     C(64): 删除H(102), 平行度=1.000
#   最终原子数: 100
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-18_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-18_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-18_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-19.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0547, 15.5062)
#     N2: (-10.4553, 15.5046)
#     N3: (-10.4506, 2.6829)
#
# [6. 补氢]
#   C顶点索引: [46, 47, 48]
#   N顶点索引: [49, 50, 51]
#   RDKit补氢后原子数: 96
#   删除顶点H数: 15
#   补C顶点H后原子数: 87
#   Imine键与X轴更平行
#     C(46): 删除H(82), 平行度=1.000
#     C(47): 删除H(83), 平行度=1.000
#     C(48): 删除H(86), 平行度=1.000
#   最终原子数: 84
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-19_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-19_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-19_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-2.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-10.4528, 15.5060)
#     N2: (-3.0512, 15.5066)
#     N3: (-10.4516, 2.6839)
#
# [6. 补氢]
#   C顶点索引: [44, 45, 46]
#   N顶点索引: [47, 48, 49]
#   RDKit补氢后原子数: 90
#   删除顶点H数: 15
#   补C顶点H后原子数: 81
#   Imine键与X轴更平行
#     C(44): 删除H(76), 平行度=1.000
#     C(45): 删除H(77), 平行度=1.000
#     C(46): 删除H(80), 平行度=1.000
#   最终原子数: 78
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-2_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-2_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-2_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-20.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.2061, 偏离 = 0.2061
#   翻转: 边平行度 = 0.9505, 偏离 = 0.0495
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-19.6716, 16.2915)
#     N2: (-19.6716, 2.4332)
#     N3: (-2.8306, 16.2907)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 120
#   删除顶点H数: 15
#   补C顶点H后原子数: 111
#   Imine键与X轴更平行
#     C(64): 删除H(106), 平行度=1.000
#     C(65): 删除H(107), 平行度=1.000
#     C(66): 删除H(110), 平行度=1.000
#   最终原子数: 108
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-20_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-20_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-20_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-21.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0003, 偏离 = 0.0003
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-17.9584, 25.8967)
#     N2: (-17.9518, 2.6796)
#     N3: (-3.0582, 25.9007)
#
# [6. 补氢]
#   C顶点索引: [72, 73, 74]
#   N顶点索引: [75, 76, 77]
#   RDKit补氢后原子数: 132
#   删除顶点H数: 15
#   补C顶点H后原子数: 123
#   Imine键与X轴更平行
#     C(72): 删除H(118), 平行度=1.000
#     C(73): 删除H(119), 平行度=1.000
#     C(74): 删除H(122), 平行度=1.000
#   最终原子数: 120
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-21_final.mol
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-1_ami-21_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-21_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-22.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.8662, 偏离 = 0.1338
#   翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0465, 20.7012)
#     N2: (-13.4502, 20.7035)
#     N3: (-13.4541, 2.6865)
#
# [6. 补氢]
#   C顶点索引: [52, 53, 54]
#   N顶点索引: [55, 56, 57]
#   RDKit补氢后原子数: 98
#   删除顶点H数: 15
#   补C顶点H后原子数: 89
#   Imine键与X轴更平行
#     C(52): 删除H(84), 平行度=1.000
#     C(53): 删除H(85), 平行度=1.000
#     C(54): 删除H(88), 平行度=1.000
#   最终原子数: 86
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-22_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-22_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-22_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-23.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8662, 偏离 = 0.1338
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-5.9504, 2.6845)
#     N2: (-5.9498, 10.3094)
#     N3: (-3.0498, 10.3091)
#
# [6. 补氢]
#   C顶点索引: [24, 25, 26]
#   N顶点索引: [27, 28, 29]
#   RDKit补氢后原子数: 56
#   删除顶点H数: 15
#   补C顶点H后原子数: 47
#   Imine键与X轴更平行
#     C(24): 删除H(42), 平行度=1.000
#     C(25): 删除H(43), 平行度=1.000
#     C(26): 删除H(46), 平行度=1.000
#   最终原子数: 44
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-23_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-23_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-23_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-24.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.4998, 偏离 = 0.4998
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0494, 7.7077)
#     N2: (-14.9519, 7.7070)
#     N3: (-14.9530, 2.6835)
#
# [6. 补氢]
#   C顶点索引: [32, 33, 34]
#   N顶点索引: [35, 36, 37]
#   RDKit补氢后原子数: 70
#   删除顶点H数: 15
#   补C顶点H后原子数: 61
#   Imine键与X轴更平行
#     C(32): 删除H(56), 平行度=1.000
#     C(33): 删除H(57), 平行度=1.000
#     C(34): 删除H(60), 平行度=1.000
#   最终原子数: 58
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-24_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-24_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-24_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-25.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8662, 偏离 = 0.1338
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-5.9504, 2.6845)
#     N2: (-3.0496, 12.9091)
#     N3: (-5.9496, 12.9094)
#
# [6. 补氢]
#   C顶点索引: [28, 29, 30]
#   N顶点索引: [31, 32, 33]
#   RDKit补氢后原子数: 60
#   删除顶点H数: 15
#   补C顶点H后原子数: 51
#   Imine键与X轴更平行
#     C(28): 删除H(46), 平行度=1.000
#     C(29): 删除H(47), 平行度=1.000
#     C(30): 删除H(50), 平行度=1.000
#   最终原子数: 48
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-25_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-25_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-25_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-26.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.4998, 偏离 = 0.4998
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.5106, 7.5444)
#     N2: (-17.7258, 7.5444)
#     N3: (-17.2672, 2.5420)
#
# [6. 补氢]
#   C顶点索引: [36, 37, 38]
#   N顶点索引: [39, 40, 41]
#   RDKit补氢后原子数: 76
#   删除顶点H数: 15
#   补C顶点H后原子数: 67
#   Imine键与X轴更平行
#     C(36): 删除H(62), 平行度=1.000
#     C(37): 删除H(63), 平行度=1.000
#     C(38): 删除H(66), 平行度=1.000
#   最终原子数: 64
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-26_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-26_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-26_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-27.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0541, 19.1544)
#     N2: (-15.1573, 2.6820)
#     N3: (-15.1612, 19.1520)
#
# [6. 补氢]
#   C顶点索引: [60, 61, 62]
#   N顶点索引: [63, 64, 65]
#   RDKit补氢后原子数: 108
#   删除顶点H数: 15
#   补C顶点H后原子数: 99
#   Imine键与X轴更平行
#     C(60): 删除H(94), 平行度=1.000
#     C(61): 删除H(95), 平行度=1.000
#     C(62): 删除H(98), 平行度=1.000
#   最终原子数: 96
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-27_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-27_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-27_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-28.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9523, 2.6841)
#     N2: (-3.0507, 23.3042)
#     N3: (-14.9521, 23.3025)
#
# [6. 补氢]
#   C顶点索引: [68, 69, 70]
#   N顶点索引: [71, 72, 73]
#   RDKit补氢后原子数: 130
#   删除顶点H数: 15
#   补C顶点H后原子数: 121
#   Imine键与X轴更平行
#     C(68): 删除H(116), 平行度=1.000
#     C(69): 删除H(117), 平行度=1.000
#     C(70): 删除H(120), 平行度=1.000
#   最终原子数: 118
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-28_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-28_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-28_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-29.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.9513, 偏离 = 0.0487
#   翻转: 边平行度 = 0.2085, 偏离 = 0.2085
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-2.8287, 10.2798)
#     N2: (-12.9735, 2.4398)
#     N3: (-12.9735, 10.2798)
#
# [6. 补氢]
#   C顶点索引: [40, 41, 42]
#   N顶点索引: [43, 44, 45]
#   RDKit补氢后原子数: 80
#   删除顶点H数: 15
#   补C顶点H后原子数: 71
#   Imine键与X轴更平行
#     C(40): 删除H(66), 平行度=1.000
#     C(41): 删除H(67), 平行度=1.000
#     C(42): 删除H(70), 平行度=1.000
#   最终原子数: 68
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-29_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-29_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-29_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-3.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0019, 偏离 = 0.0019
#   翻转: 边平行度 = 0.8671, 偏离 = 0.1329
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9692, 15.4985)
#     N2: (-14.9692, 2.6927)
#     N3: (-3.0535, 15.4866)
#
# [6. 补氢]
#   C顶点索引: [54, 55, 56]
#   N顶点索引: [57, 58, 59]
#   RDKit补氢后原子数: 104
#   删除顶点H数: 15
#   补C顶点H后原子数: 95
#   Imine键与X轴更平行
#     C(54): 删除H(90), 平行度=1.000
#     C(55): 删除H(91), 平行度=1.000
#     C(56): 删除H(94), 平行度=1.000
#   最终原子数: 92
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-3_final.mol
# [21:31:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-1_ami-3_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-3_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-30.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9544, 2.6821)
#     N2: (-14.9558, 15.5034)
#     N3: (-3.0532, 15.5052)
#
# [6. 补氢]
#   C顶点索引: [50, 51, 52]
#   N顶点索引: [53, 54, 55]
#   RDKit补氢后原子数: 99
#   删除顶点H数: 15
#   补C顶点H后原子数: 90
#   Imine键与X轴更平行
#     C(50): 删除H(85), 平行度=1.000
#     C(51): 删除H(86), 平行度=1.000
#     C(52): 删除H(89), 平行度=1.000
#   最终原子数: 87
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-30_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-30_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-30_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-4.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.9513, 偏离 = 0.0487
#   翻转: 边平行度 = 0.2085, 偏离 = 0.2085
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-2.8289, 16.3088)
#     N2: (-19.6605, 16.3088)
#     N3: (-19.6603, 2.4399)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 120
#   删除顶点H数: 15
#   补C顶点H后原子数: 111
#   Imine键与X轴更平行
#     C(64): 删除H(106), 平行度=1.000
#     C(65): 删除H(107), 平行度=1.000
#     C(66): 删除H(110), 平行度=1.000
#   最终原子数: 108
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-4_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-4_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-4_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-5.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9519, 2.6817)
#     N2: (-14.9563, 20.6980)
#     N3: (-3.0546, 20.7006)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 120
#   删除顶点H数: 15
#   补C顶点H后原子数: 111
#   Imine键与X轴更平行
#     C(64): 删除H(106), 平行度=1.000
#     C(65): 删除H(107), 平行度=1.000
#     C(66): 删除H(110), 平行度=1.000
#   最终原子数: 108
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-5_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-5_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-5_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-6.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.4961, 偏离 = 0.4961
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9115, 12.9343)
#     N2: (-14.9115, 2.7424)
#     N3: (-2.9869, 12.8866)
#
# [6. 补氢]
#   C顶点索引: [46, 47, 48]
#   N顶点索引: [49, 50, 51]
#   RDKit补氢后原子数: 94
#   删除顶点H数: 15
#   补C顶点H后原子数: 85
#   Imine键与X轴更平行
#     C(46): 删除H(80), 平行度=1.000
#     C(47): 删除H(81), 平行度=1.000
#     C(48): 删除H(84), 平行度=1.000
#   最终原子数: 82
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-6_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-6_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-6_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-7.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-14.9540, 2.6821)
#     N2: (-14.9559, 15.5033)
#     N3: (-3.0535, 15.5055)
#
# [6. 补氢]
#   C顶点索引: [50, 51, 52]
#   N顶点索引: [53, 54, 55]
#   RDKit补氢后原子数: 100
#   删除顶点H数: 15
#   补C顶点H后原子数: 91
#   Imine键与X轴更平行
#     C(50): 删除H(86), 平行度=1.000
#     C(51): 删除H(87), 平行度=1.000
#     C(52): 删除H(90), 平行度=1.000
#   最终原子数: 88
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-7_final.mol
# [21:31:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-1_ami-7_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-7_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-8.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.4572, 偏离 = 0.4572
#   翻转: 边平行度 = 0.9988, 偏离 = 0.0012
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.4279, 14.9240)
#     N2: (-17.6548, 14.9240)
#     N3: (-17.2715, 2.5703)
#
# [6. 补氢]
#   C顶点索引: [52, 53, 54]
#   N顶点索引: [55, 56, 57]
#   RDKit补氢后原子数: 104
#   删除顶点H数: 15
#   补C顶点H后原子数: 95
#   Imine键与X轴更平行
#     C(52): 删除H(90), 平行度=1.000
#     C(53): 删除H(91), 平行度=1.000
#     C(54): 删除H(94), 平行度=1.000
#   最终原子数: 92
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-8_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-8_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-8_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-1.mol
#   ami: ami-result\ami-9.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8661, 偏离 = 0.1339
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (5.9508, 2.5129)
#     C2: (5.9508, -2.5120)
#     C3: (-1.4506, -2.5121)
#   N顶点坐标:
#     N1: (-3.0528, 20.7026)
#     N2: (-14.9550, 2.6828)
#     N3: (-14.9565, 20.6998)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 116
#   删除顶点H数: 15
#   补C顶点H后原子数: 107
#   Imine键与X轴更平行
#     C(64): 删除H(102), 平行度=1.000
#     C(65): 删除H(103), 平行度=1.000
#     C(66): 删除H(106), 平行度=1.000
#   最终原子数: 104
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-1_ami-9_final.mol
#   结构图已保存: ./cif_results/dimer_ald-1_ami-9_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-1_ami-9_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-1.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (18.7029, -14.2086)
#     N2: (18.7031, -3.9859)
#     N3: (11.3025, -14.2082)
#
# [6. 补氢]
#   C顶点索引: [79, 80, 81]
#   N顶点索引: [82, 83, 84]
#   RDKit补氢后原子数: 145
#   删除顶点H数: 15
#   补C顶点H后原子数: 136
#   Imine键与X轴更平行
#     C(79): 删除H(131), 平行度=1.000
#     C(80): 删除H(133), 平行度=1.000
#     C(81): 删除H(134), 平行度=1.000
#   最终原子数: 133
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-1_final.mol
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-10_ami-1_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-1_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-10.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0003, 偏离 = 0.0003
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (18.7015, -16.8091)
#     N2: (18.7048, -3.9871)
#     N3: (11.2998, -16.8072)
#
# [6. 补氢]
#   C顶点索引: [83, 84, 85]
#   N顶点索引: [86, 87, 88]
#   RDKit补氢后原子数: 149
#   删除顶点H数: 15
#   补C顶点H后原子数: 140
#   Imine键与X轴更平行
#     C(83): 删除H(135), 平行度=1.000
#     C(84): 删除H(137), 平行度=1.000
#     C(85): 删除H(138), 平行度=1.000
#   最终原子数: 137
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-10_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-10_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-10_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-11.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.3005, -22.0065)
#     N2: (23.2025, -3.9869)
#     N3: (23.1992, -22.0068)
#
# [6. 补氢]
#   C顶点索引: [103, 104, 105]
#   N顶点索引: [106, 107, 108]
#   RDKit补氢后原子数: 185
#   删除顶点H数: 15
#   补C顶点H后原子数: 176
#   Imine键与X轴更平行
#     C(103): 删除H(171), 平行度=1.000
#     C(104): 删除H(173), 平行度=1.000
#     C(105): 删除H(174), 平行度=1.000
#   最终原子数: 173
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-11_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-11_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-11_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-12.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.5019, 偏离 = 0.4981
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.2697, -14.2013)
#     N2: (32.1648, -14.2013)
#     N3: (32.1887, -3.9994)
#
# [6. 补氢]
#   C顶点索引: [97, 98, 99]
#   N顶点索引: [100, 101, 102]
#   RDKit补氢后原子数: 175
#   删除顶点H数: 15
#   补C顶点H后原子数: 166
#   Imine键与X轴更平行
#     C(97): 删除H(161), 平行度=1.000
#     C(98): 删除H(163), 平行度=1.000
#     C(99): 删除H(164), 平行度=1.000
#   最终原子数: 163
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-12_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-12_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-12_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-13.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.2942, -22.0044)
#     N2: (27.7013, -3.9887)
#     N3: (27.7026, -22.0078)
#
# [6. 补氢]
#   C顶点索引: [117, 118, 119]
#   N顶点索引: [120, 121, 122]
#   RDKit补氢后原子数: 207
#   删除顶点H数: 15
#   补C顶点H后原子数: 198
#   Imine键与X轴更平行
#     C(117): 删除H(193), 平行度=1.000
#     C(118): 删除H(195), 平行度=1.000
#     C(119): 删除H(196), 平行度=1.000
#   最终原子数: 195
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-13_final.mol
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:31:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-10_ami-13_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-13_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-14.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.5001, 偏离 = 0.4999
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.3008, -9.0085)
#     N2: (18.7037, -9.0114)
#     N3: (18.7054, -3.9879)
#
# [6. 补氢]
#   C顶点索引: [65, 66, 67]
#   N顶点索引: [68, 69, 70]
#   RDKit补氢后原子数: 121
#   删除顶点H数: 15
#   补C顶点H后原子数: 112
#   Imine键与X轴更平行
#     C(65): 删除H(107), 平行度=1.000
#     C(66): 删除H(109), 平行度=1.000
#     C(67): 删除H(110), 平行度=1.000
#   最终原子数: 109
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-14_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-14_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-14_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-15.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.5018, 偏离 = 0.4982
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.2703, -14.2010)
#     N2: (32.1873, -3.9991)
#     N3: (32.1637, -14.2010)
#
# [6. 补氢]
#   C顶点索引: [100, 101, 102]
#   N顶点索引: [103, 104, 105]
#   RDKit补氢后原子数: 176
#   删除顶点H数: 15
#   补C顶点H后原子数: 167
#   Imine键与X轴更平行
#     C(100): 删除H(162), 平行度=1.000
#     C(101): 删除H(164), 平行度=1.000
#     C(102): 删除H(165), 平行度=1.000
#   最终原子数: 164
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-15_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-15_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-15_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-16.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0020, 偏离 = 0.0020
#   翻转: 边平行度 = 0.8668, 偏离 = 0.1332
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.3209, -24.5770)
#     N2: (27.7342, -3.9809)
#     N3: (27.7466, -24.5770)
#
# [6. 补氢]
#   C顶点索引: [117, 118, 119]
#   N顶点索引: [120, 121, 122]
#   RDKit补氢后原子数: 205
#   删除顶点H数: 15
#   补C顶点H后原子数: 196
#   Imine键与X轴更平行
#     C(117): 删除H(191), 平行度=1.000
#     C(118): 删除H(193), 平行度=1.000
#     C(119): 删除H(194), 平行度=1.000
#   最终原子数: 193
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-16_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-16_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-16_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-17.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.4999, 偏离 = 0.4999
#   翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.2956, -16.8065)
#     N2: (27.6985, -16.8144)
#     N3: (27.7061, -3.9931)
#
# [6. 补氢]
#   C顶点索引: [95, 96, 97]
#   N顶点索引: [98, 99, 100]
#   RDKit补氢后原子数: 171
#   删除顶点H数: 15
#   补C顶点H后原子数: 162
#   Imine键与X轴更平行
#     C(95): 删除H(157), 平行度=1.000
#     C(96): 删除H(159), 平行度=1.000
#     C(97): 删除H(160), 平行度=1.000
#   最终原子数: 159
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-17_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-17_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-10_ami-17_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-10.mol
#   ami: ami-result\ami-18.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.8663, 偏离 = 0.1337
#   翻转: 边平行度 = 0.0010, 偏离 = 0.0010
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (9.7025, 6.4102)
#     C2: (-11.2020, -3.8118)
#     C3: (-11.2024, 6.4102)
#   N顶点坐标:
#     N1: (11.2735, -21.9831)
#     N2: (26.2256, -3.9980)
#     N3: (26.1962, -21.9958)
#
# [6. 补氢]
#   C顶点索引: [101, 102, 103]
#   N顶点索引: [104, 105, 106]
#   RDKit补氢后原子数: 173
#   删除顶点H数: 15
#   补C顶点H后原子数: 164
#   Imine键与X轴更平行
#     C(101): 删除H(159), 平行度=1.000
#     C(102): 删除H(161), 平行度=1.000
#     C(103): 删除H(162), 平行度=1.000
#   最终原子数: 161
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-10_ami-18_final.mol
#   结构图已保存: ./cif_results/dimer_ald-10_ami-18_final.png
# ...
#     N2: (-17.6726, 16.5296)
#     N3: (-17.6752, 11.5062)
#
# [6. 补氢]
#   C顶点索引: [68, 69, 70]
#   N顶点索引: [71, 72, 73]
#   RDKit补氢后原子数: 132
#   删除顶点H数: 15
#   补C顶点H后原子数: 123
#   Imine键与X轴更平行
#     C(68): 删除H(117), 平行度=1.000
#     C(69): 删除H(120), 平行度=1.000
#     C(70): 删除H(121), 平行度=1.000
#   最终原子数: 120
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-24_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-24_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-24_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-25.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0004, 偏离 = 0.0004
#   翻转: 边平行度 = 0.8660, 偏离 = 0.1340
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-8.6727, 11.5045)
#     N2: (-5.7688, 21.7282)
#     N3: (-8.6688, 21.7293)
#
# [6. 补氢]
#   C顶点索引: [64, 65, 66]
#   N顶点索引: [67, 68, 69]
#   RDKit补氢后原子数: 122
#   删除顶点H数: 15
#   补C顶点H后原子数: 113
#   Imine键与X轴更平行
#     C(64): 删除H(107), 平行度=1.000
#     C(65): 删除H(110), 平行度=1.000
#     C(66): 删除H(111), 平行度=1.000
#   最终原子数: 110
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-25_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-25_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-25_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-26.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.5001, 偏离 = 0.4999
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-6.2329, 16.3630)
#     N2: (-20.4481, 16.3630)
#     N3: (-19.9895, 11.3606)
#
# [6. 补氢]
#   C顶点索引: [72, 73, 74]
#   N顶点索引: [75, 76, 77]
#   RDKit补氢后原子数: 138
#   删除顶点H数: 15
#   补C顶点H后原子数: 129
#   Imine键与X轴更平行
#     C(72): 删除H(123), 平行度=1.000
#     C(73): 删除H(126), 平行度=1.000
#     C(74): 删除H(127), 平行度=1.000
#   最终原子数: 126
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-26_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-26_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-26_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-27.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8658, 偏离 = 0.1342
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-5.7714, 27.9735)
#     N2: (-17.8795, 11.5047)
#     N3: (-17.8784, 27.9747)
#
# [6. 补氢]
#   C顶点索引: [96, 97, 98]
#   N顶点索引: [99, 100, 101]
#   RDKit补氢后原子数: 170
#   删除顶点H数: 15
#   补C顶点H后原子数: 161
#   Imine键与X轴更平行
#     C(96): 删除H(155), 平行度=1.000
#     C(97): 删除H(158), 平行度=1.000
#     C(98): 删除H(159), 平行度=1.000
#   最终原子数: 158
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-27_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-27_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-27_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-28.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0003, 偏离 = 0.0003
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6746, 11.5068)
#     N2: (-5.7667, 32.1233)
#     N3: (-17.6681, 32.1252)
#
# [6. 补氢]
#   C顶点索引: [104, 105, 106]
#   N顶点索引: [107, 108, 109]
#   RDKit补氢后原子数: 192
#   删除顶点H数: 15
#   补C顶点H后原子数: 183
#   Imine键与X轴更平行
#     C(104): 删除H(177), 平行度=1.000
#     C(105): 删除H(180), 平行度=1.000
#     C(106): 删除H(181), 平行度=1.000
#   最终原子数: 180
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-28_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-28_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-28_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-29.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.9512, 偏离 = 0.0488
#   翻转: 边平行度 = 0.2088, 偏离 = 0.2088
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-5.5509, 19.0984)
#     N2: (-15.6958, 11.2584)
#     N3: (-15.6958, 19.0984)
#
# [6. 补氢]
#   C顶点索引: [76, 77, 78]
#   N顶点索引: [79, 80, 81]
#   RDKit补氢后原子数: 142
#   删除顶点H数: 15
#   补C顶点H后原子数: 133
#   Imine键与X轴更平行
#     C(76): 删除H(127), 平行度=1.000
#     C(77): 删除H(130), 平行度=1.000
#     C(78): 删除H(131), 平行度=1.000
#   最终原子数: 130
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-29_final.mol
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   结构图已保存: ./cif_results/dimer_ald-9_ami-29_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-29_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-3.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0023, 偏离 = 0.0023
#   翻转: 边平行度 = 0.8669, 偏离 = 0.1331
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6915, 24.3171)
#     N2: (-17.6915, 11.5113)
#     N3: (-5.7758, 24.3052)
#
# [6. 补氢]
#   C顶点索引: [90, 91, 92]
#   N顶点索引: [93, 94, 95]
#   RDKit补氢后原子数: 166
#   删除顶点H数: 15
#   补C顶点H后原子数: 157
#   Imine键与X轴更平行
#     C(90): 删除H(151), 平行度=1.000
#     C(91): 删除H(154), 平行度=1.000
#     C(92): 删除H(155), 平行度=1.000
#   最终原子数: 154
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-3_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-3_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-3_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-30.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6767, 11.5048)
#     N2: (-17.6742, 24.3260)
#     N3: (-5.7716, 24.3243)
#
# [6. 补氢]
#   C顶点索引: [86, 87, 88]
#   N顶点索引: [89, 90, 91]
#   RDKit补氢后原子数: 161
#   删除顶点H数: 15
#   补C顶点H后原子数: 152
#   Imine键与X轴更平行
#     C(86): 删除H(146), 平行度=1.000
#     C(87): 删除H(149), 平行度=1.000
#     C(88): 删除H(150), 平行度=1.000
#   最终原子数: 149
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-30_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-30_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-30_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-4.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.9512, 偏离 = 0.0488
#   翻转: 边平行度 = 0.2089, 偏离 = 0.2089
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-5.5512, 25.1274)
#     N2: (-22.3828, 25.1274)
#     N3: (-22.3826, 11.2585)
#
# [6. 补氢]
#   C顶点索引: [100, 101, 102]
#   N顶点索引: [103, 104, 105]
#   RDKit补氢后原子数: 182
#   删除顶点H数: 15
#   补C顶点H后原子数: 173
#   Imine键与X轴更平行
#     C(100): 删除H(167), 平行度=1.000
#     C(101): 删除H(170), 平行度=1.000
#     C(102): 删除H(171), 平行度=1.000
#   最终原子数: 170
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-4_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-4_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-4_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-5.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0001, 偏离 = 0.0001
#   翻转: 边平行度 = 0.8658, 偏离 = 0.1342
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6742, 11.5044)
#     N2: (-17.6731, 29.5207)
#     N3: (-5.7714, 29.5197)
#
# [6. 补氢]
#   C顶点索引: [100, 101, 102]
#   N顶点索引: [103, 104, 105]
#   RDKit补氢后原子数: 182
#   删除顶点H数: 15
#   补C顶点H后原子数: 173
#   Imine键与X轴更平行
#     C(100): 删除H(167), 平行度=1.000
#     C(101): 删除H(170), 平行度=1.000
#     C(102): 删除H(171), 平行度=1.000
#   最终原子数: 170
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-5_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-5_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-5_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-6.mol
#
# [2. 计算边平行度]
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
#   不翻转: 边平行度 = 1.0000, 偏离 = 0.0000
#   翻转: 边平行度 = 0.4964, 偏离 = 0.4964
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6338, 21.7529)
#     N2: (-17.6338, 11.5610)
#     N3: (-5.7092, 21.7052)
#
# [6. 补氢]
#   C顶点索引: [82, 83, 84]
#   N顶点索引: [85, 86, 87]
#   RDKit补氢后原子数: 156
#   删除顶点H数: 15
#   补C顶点H后原子数: 147
#   Imine键与X轴更平行
#     C(82): 删除H(141), 平行度=1.000
#     C(83): 删除H(144), 平行度=1.000
#     C(84): 删除H(145), 平行度=1.000
#   最终原子数: 144
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-6_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-6_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-6_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-7.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-17.6762, 11.5047)
#     N2: (-17.6743, 24.3260)
#     N3: (-5.7719, 24.3245)
#
# [6. 补氢]
#   C顶点索引: [86, 87, 88]
#   N顶点索引: [89, 90, 91]
#   RDKit补氢后原子数: 162
#   删除顶点H数: 15
#   补C顶点H后原子数: 153
#   Imine键与X轴更平行
#     C(86): 删除H(147), 平行度=1.000
#     C(87): 删除H(150), 平行度=1.000
#     C(88): 删除H(151), 平行度=1.000
#   最终原子数: 150
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-7_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-7_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-7_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-8.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.4575, 偏离 = 0.4575
#   翻转: 边平行度 = 0.9988, 偏离 = 0.0012
#   ✓ 选择: 翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-6.1502, 23.7426)
#     N2: (-20.3771, 23.7426)
#     N3: (-19.9938, 11.3890)
#
# [6. 补氢]
#   C顶点索引: [88, 89, 90]
#   N顶点索引: [91, 92, 93]
#   RDKit补氢后原子数: 166
#   删除顶点H数: 15
#   补C顶点H后原子数: 157
#   Imine键与X轴更平行
#     C(88): 删除H(151), 平行度=1.000
#     C(89): 删除H(154), 平行度=1.000
#     C(90): 删除H(155), 平行度=1.000
#   最终原子数: 154
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-8_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-8_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-8_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# ======================================================================
#   COF Dimer 完整流程
# ======================================================================
#
# [1. 读取分子文件]
#   ald: ald-result\ald-9.mol
#   ami: ami-result\ami-9.mol
#
# [2. 计算边平行度]
#   不翻转: 边平行度 = 0.0002, 偏离 = 0.0002
#   翻转: 边平行度 = 0.8659, 偏离 = 0.1341
#   ✓ 选择: 不翻转
#
# [3. 合并分子]
#   ald剩余顶点: 3
#   ami剩余顶点: 3
#
# [4. 添加顶点原子]
#   添加C顶点: 3个
#   添加N顶点: 3个
#
# [5. 对齐到网格]
#   C顶点坐标:
#     C1: (-4.1729, 21.7252)
#     C2: (16.7322, 21.7252)
#     C3: (16.7325, 11.5033)
#   N顶点坐标:
#     N1: (-5.7696, 29.5217)
#     N2: (-17.6773, 11.5055)
#     N3: (-17.6733, 29.5224)
#
# [6. 补氢]
#   C顶点索引: [100, 101, 102]
#   N顶点索引: [103, 104, 105]
#   RDKit补氢后原子数: 178
#   删除顶点H数: 15
#   补C顶点H后原子数: 169
#   Imine键与X轴更平行
#     C(100): 删除H(163), 平行度=1.000
#     C(101): 删除H(166), 平行度=1.000
#     C(102): 删除H(167), 平行度=1.000
#   最终原子数: 166
#
# [7. 保存结果]
#   MOL文件: ./cif_results/dimer_ald-9_ami-9_final.mol
#   结构图已保存: ./cif_results/dimer_ald-9_ami-9_final.png
#   对齐MOL文件: ./cif_results/dimer_ald-9_ami-9_aligned.mol
#
# ======================================================================
# 完成!
# ======================================================================
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [21:34:06] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.

# %%
### 第二次：角度为-120度 # target_ny_dir = rotate_vec_2d(nc_dir, -120)
#ald_mols=['ald-result/ald-6.mol','ald-result/ald-27.mol']
#nums=[9,15,17,18,19,20,21,23,24,26,28,30,33,34,36,37,38,39,40]
#ald_mols=[f'ald-result/ald-{n}.mol' for n in nums]
